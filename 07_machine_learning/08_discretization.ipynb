# %% [markdown]
# # Discretization
# `Data discretization` is a preprocessing technique used to transform continuous or numerical data into discrete categories or bins. This process can be particularly useful for machine learning algorithms that handle categorical data more effectively than continuous data. It can also help to improve model interpretability and handle outliers more robustly.

# %%
# import libraries
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import KBinsDiscretizer

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#impute missing values
df['age'] = df['age'].fillna(df['age'].median())
df['fare']= df['fare'].fillna(df['fare'].median())

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(df['age'], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Age discretization
age_discretizer = KBinsDiscretizer(n_bins=3, encode='ordinal', strategy='uniform')
df['age_bin'] = age_discretizer.fit_transform(df[['age']])
df.head()
# Out:
# C:\Users\Kaleem KM\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_discretization.py:248: FutureWarning: In version 1.5 onwards, subsample=200_000 will be used by default. Set subsample explicitly to silence this warning in the mean time. Set subsample=None to disable subsampling explicitly.
#   warnings.warn(
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_bin
# 0    man        True  NaN  Southampton    no  False      0.0
# 1  woman       False    C    Cherbourg   yes  False      1.0
# 2  woman       False  NaN  Southampton   yes   True      0.0
# 3  woman       False    C  Southampton   yes  False      1.0
# 4    man        True  NaN  Southampton    no   True      1.0

# %%
sns.histplot(df, x='age', hue = 'age_bin')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Age discretization
age_discretizer = KBinsDiscretizer(n_bins=2, encode='ordinal', strategy='kmeans')
df['age_bin'] = age_discretizer.fit_transform(df[['age']])
df.head()
# Out:
# C:\Users\Kaleem KM\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_discretization.py:248: FutureWarning: In version 1.5 onwards, subsample=200_000 will be used by default. Set subsample explicitly to silence this warning in the mean time. Set subsample=None to disable subsampling explicitly.
#   warnings.warn(
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_bin
# 0    man        True  NaN  Southampton    no  False      0.0
# 1  woman       False    C    Cherbourg   yes  False      1.0
# 2  woman       False  NaN  Southampton   yes   True      0.0
# 3  woman       False    C  Southampton   yes  False      0.0
# 4    man        True  NaN  Southampton    no   True      0.0

# %%
sns.histplot(df, x='age', hue = 'age_bin')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# pandas method for manual binning
df['age_bin2'] = pd.cut(df['age'], bins=3, labels=['young', 'middle', 'old'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_bin age_bin2
# 0    man        True  NaN  Southampton    no  False      0.0    young
# 1  woman       False    C    Cherbourg   yes  False      1.0   middle
# 2  woman       False  NaN  Southampton   yes   True      0.0    young
# 3  woman       False    C  Southampton   yes  False      0.0   middle
# 4    man        True  NaN  Southampton    no   True      0.0   middle

# %%
sns.histplot(df, x='age', hue = 'age_bin2')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# define the bins
bins = [0,10,18,30, 50, 80]
labels = ['child', 'teenager', 'young', 'adult', 'old']

# apply the binning
df['age_bin3'] = pd.cut(df['age'], bins=bins, labels=labels)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_bin age_bin2 age_bin3
# 0    man        True  NaN  Southampton    no  False      0.0    young    young
# 1  woman       False    C    Cherbourg   yes  False      1.0   middle    adult
# 2  woman       False  NaN  Southampton   yes   True      0.0    young    young
# 3  woman       False    C  Southampton   yes  False      0.0   middle    adult
# 4    man        True  NaN  Southampton    no   True      0.0   middle    adult

# %%
sns.histplot(df, x='age', hue = 'age_bin3')
# Out:
# <Axes: xlabel='age', ylabel='Count'>
